# %%
import pandas as pd

import numpy as np

import string

from nltk.corpus import stopwords

from nltk import pos_tag

from nltk.corpus import wordnet

from nltk.stem import WordNetLemmatizer

import re

# %%
#function that processes the comments and returns clean_comments

def text_preprocessing(data):

    

    #convert to lowercase
    data['clean_comments'] = data['comments'].str.lower()

    #removing empty columns
    data['clean_comments'].replace('', np.nan, inplace=True)
    data.dropna(subset=['clean_comments'], inplace=True)

    #removing punctuations
    punctuation = string.punctuation
    data['clean_comments'] = data['clean_comments'].astype(str)
    data['clean_comments'] = data['clean_comments'].apply(lambda x: x.translate(str.maketrans('','',punctuation)))

    #removing stopwords
    STOPWORDS = set(stopwords.words('english'))
    data['clean_comments'] = data['clean_comments'].apply(lambda x: " ".join([w for w in x.split() if w not in STOPWORDS]))

    #remove non english words
    #WORDS = set(words.words())
    #data['clean_comments'] = data['clean_comments'].apply(lambda x: " ".join(w for w in x.split() if w in WORDS))

    #removing special characters
    data['clean_comments'] = data['clean_comments'].apply(lambda x: re.sub('[^a-zA-Z0-9]', ' ', x))
    data['clean_comments'] = data['clean_comments'].apply(lambda x: re.sub('\s+', ' ', x))

    #removing urls and html tags
    data['clean_comments'] = data['clean_comments'].apply(lambda x: re.sub(r'https?://\S+www\.\S+', ' ', x))
    data['clean_comments'] = data['clean_comments'].apply(lambda x: re.sub(r'<.*?>', ' ', x))

    #stemization
    #ps = PorterStemmer()
    #data['clean_comments'] = data['clean_comments'].apply(lambda x: " ".join([ps.stem(w) for w in x.split()]))

    #lemmatization and pos tagging
    lemmatizer = WordNetLemmatizer()
    wordnet_map = {"N":wordnet.NOUN,"V":wordnet.VERB,"J":wordnet.ADJ,"R":wordnet.ADV}
    data['clean_comments'] = data['clean_comments'].apply(lambda x: " ".join([lemmatizer.lemmatize(w,wordnet_map.get(pos[0],wordnet.NOUN)) for w, pos in pos_tag(x.split())]))
    
    #removing empty columns
    data['clean_comments'].replace('', np.nan, inplace=True)
    data.dropna(subset=['clean_comments'], inplace=True)

    #removing null value
    #data['clean_comments'].dropna(how = any, axis = 0)

    #word tokanize
    #data['clean_comments'] = data['clean_comments'].apply(lambda x: word_tokenize(x))
    #data
    
    #reset index
    data.reset_index(drop=True)
    #using globle variable i and modifying it after saving into csv
    global y
    data.to_csv("C:\\Users\\11ani\\OneDrive\\Desktop\\project 7th sem code\\clean_comments\\traindata\\"+str(y)+"tesclean.csv")
    y = y+1
    print(data)

# %%
y = 8

for i in range(8,12):
    data = pd.read_csv("C:\\Users\\11ani\\OneDrive\\Desktop\\project 7th sem code\\raw_comments\\traindata\\"+str(i)+"tes.csv", index_col=[0])
    text_preprocessing(data)
# Out:
#                                               comments  sentiments  \
# 0    What I'm going to say is that I never imagined...           1
# 1    Please continue this series. What happened aft...           1
# 2    Would love to see more of our history's video,...           1
# 3    They will never be forgotten. Salute to our ma...           1
# 4    The level of editing , animation , voice, rese...           1
# ..                                                 ...         ...
# 425                       Search ex-muslim on YouTube.           1
# 426  I really don't like your thumbnail. It's ridic...           1
# 427                                Bir sahid lal salam           1
# 429                                               Yosh           1
# 430                                 Rajtantra jindabad           1
#
#                                         clean_comments
# 0    im go say never imagine member nation finest t...
# 1    please continue series happen rana collapse lo...
# 2    would love see historys video brother hugely r...
# 3                           never forget salute martyr
# 4    level edit animation voice research everything...
# ..                                                 ...
# 425                            search exmuslim youtube
# 426  really dont like thumbnail ridiculous mauritiu...
# 427                                bir sahid lal salam
# 429                                               yosh
# 430                                 rajtantra jindabad
#
# [382 rows x 3 columns]
#                                               comments  sentiments  \
# 0    The amount of research and hardwork you put in...           1
# 1    you're doing the great job brother, even socia...           1
# 2    Finally someone came up with the real stories ...           1
# 3    Been following The Nepali Comment since the Ci...           1
# 5    Great job. Every future generations should wat...           1
# ..                                                 ...         ...
# 276                                       Jai ho sahid           1
# 277  K Tiktok jasto part part banai rako hola, sidh...           1
# 278                                               uuhg           1
# 279       I am going to unsubscribe your channel sorry           1
# 280  Yo mugini eutai season ma hunelai lyang garira...           1
#
#                                         clean_comments
# 0    amount research hardwork put videos much appre...
# 1    youre great job brother even social teacher re...
# 2    finally someone come real story past nepal kud...
# 3    follow nepali comment since civil war series c...
# 5    great job every future generation watch series...
# ..                                                 ...
# 276                                       jai ho sahid
# 277  k tiktok jasto part part banai rako hola sidha...
# 278                                               uuhg
# 279                       go unsubscribe channel sorry
# 280  yo mugini eutai season hunelai lyang garira k ...
#
# [261 rows x 3 columns]
#                                               comments  sentiments  \
# 0    Thank you everyone for such a great response. ...           1
# 1    I arguably think that our country got way back...           1
# 2    I had never thought the real story of the same...           1
# 3      Thanks Martyrs may making Nepal to this stage .           1
# 4    Hug respect to Martyrs.\nThis kind of content ...           1
# ..                                                 ...         ...
# 545                                  Hello hello hello           1
# 546                                               Getb           1
# 547                                                  E           1
# 548                                              Part2           1
# 549                                       I hate ranas           1
#
#                                         clean_comments
# 0    thank everyone great response want say english...
# 1    arguably think country get way backward due ra...
# 2    never think real story martyr study back schoo...
# 3                   thanks martyr may make nepal stage
# 4    hug respect martyr kind content make frequentl...
# ..                                                 ...
# 545                                  hello hello hello
# 546                                               getb
# 547                                                  e
# 548                                              part2
# 549                                          hate rana
#
# [505 rows x 3 columns]
#                                               comments  sentiments  \
# 0    This video is very informative. I had seen the...           1
# 1    A bitter truth everyone needs to know.. Thanks...           1
# 2    My father lost all his earning because of this...           1
# 3    Your insights on these ground reality of Nepal...           1
# 4    I really appreciate how respectful you are to ...           1
# ..                                                 ...         ...
# 263                                 #sunildarzeeshorts           1
# 264                          Yo andolan ma mah pani xu           1
# 265               Ahilea prachada deu le here saku vo            1
# 266                      Yo saab tharu haru ko kaam ho           1
# 267        Muji haru lini bela linxa dini bela case re           1
#
#                                         clean_comments
# 0    video informative see victim protest maitighar...
# 1    bitter truth everyone need know thanks make vi...
# 2    father lose earn guy give dad 4 lakh weve alre...
# 3    insight ground reality nepal common people eye...
# 4    really appreciate respectful people content go...
# ..                                                 ...
# 263                                  sunildarzeeshorts
# 264                             yo andolan mah pani xu
# 265                     ahilea prachada deu le saku vo
# 266                      yo saab tharu haru ko kaam ho
# 267           muji haru lini bela linxa dini bela case
#
# [253 rows x 3 columns]
#                                               comments  sentiments  \
# 1    I see potential in this channel to become the ...           1
# 2    Past 2-3 years i was only watching dhruv rathe...           1
# 3    This is True rise of Genuine Content creators ...           1
# 4    Very well presented !!\nThis is what new gener...           1
# 5    Amazing synthesis of the whole situation you g...           1
# ..                                                 ...         ...
# 135                                   Great content...           1
# 136  I still remember this day when Prachanda tried...           1
# 137                                  Huge appreciation           1
# 138  Army should always be under the government's c...           1
# 139  I guess Army and king, both were on the side o...           1
#
#                                         clean_comments
# 1    see potential channel become trust youtube cha...
# 2    past 23 year watch dhruv rathee gain kind know...
# 3    true rise genuine content creator nepal hat br...
# 4    well present new generation nepali youth expec...
# 5    amaze synthesis whole situation guy part maois...
# ..                                                 ...
# 135                                      great content
# 136  still remember day prachanda tried fire army c...
# 137                                  huge appreciation
# 138   army always government control shouldnt autonomy
# 139  guess army king side maoist witness say army l...
#
# [138 rows x 3 columns]
#                                               comments  sentiments  \
# 0    Thank you everyone for showing such  unexpecte...           1
# 1    I m a newar from Bhaktapur. We were totally un...           1
# 2    This video has changed my perception towards C...           1
# 3    you are right. Most of us in terai consider ou...           1
# 4    We grew up in a society where we were taught t...           1
# ..                                                 ...         ...
# 808                                    Ck raut best ️🫰           1
# 809                                               Dslr           1
# 810                                         Jaysiyaram           1
# 811  Madhesii ko Future nepal ma xina madhess ma x....           1
# 812                  Madhess dess ban x....jai madhess           1
#
#                                         clean_comments
# 0    thank everyone show unexpected love thanks nep...
# 1    newar bhaktapur totally unaware problem face b...
# 2    video change perception towards ck raut actual...
# 3    right u terai consider nepali born land grow w...
# 4    grow society taught madhesi people like indian...
# ..                                                 ...
# 808                                       ck raut best
# 809                                               dslr
# 810                                         jaysiyaram
# 811  madhesii ko future nepal xina madhess xnepalii...
# 812                       madhess des ban xjai madhess
#
# [763 rows x 3 columns]
#                                               comments  sentiments  \
# 0    The main reason for downfall/situation of Gove...           1
# 1    I was in private school, we were forced to stu...           1
# 2    The education system of Nepal had bugged me fo...           1
# 3    Me and my friend back in days paid Rs 500 per ...           1
# 4    As a young private school teacher, I have alwa...           1
# ..                                                 ...         ...
# 660                                       Dukha lagcha           1
# 661                                         Chor haruu           1
# 662                                     Irritating bgm           1
# 663  Nepali veda ho...ani neta ra thula business ma...           1
# 664  Very shallow analysis, you think you will know...           1
#
#                                         clean_comments
# 0    main reason downfallsituation government schoo...
# 1    private school force study hard get mark often...
# 2    education system nepal bug long time great con...
# 3    friend back day pay rs 500 per month class 10 ...
# 4    young private school teacher always understood...
# ..                                                 ...
# 660                                       dukha lagcha
# 661                                         chor haruu
# 662                                       irritate bgm
# 663  nepali veda hoani neta ra thula business man h...
# 664  shallow analysis think know school well kid we...
#
# [638 rows x 3 columns]
#                                               comments  sentiments  \
# 0           Congratulations brother. Long way to go!!            1
# 1    I loved how you didn't hesitate to show your E...           1
# 2          The editor did his part in the gf question!           1
# 3    In order to understand a country better, we ne...           1
# 4    keep up your work man! nepal needs young inves...           1
# ..                                                 ...         ...
# 249  MALAI PANI TAPAI KO VIDEO HERERA MA NI SAKCHU ...           1
# 250                                argentina argentina           1
# 251                                              trujt           1
# 252                                          DC>Marvel           1
# 253                                   Average contents           1
#
#                                         clean_comments
# 0                   congratulation brother long way go
# 1    love didnt hesitate show earn directly turn yo...
# 2                              editor part gf question
# 3    order understand country well need content wel...
# 4    keep work man nepal need young investigative y...
# ..                                                 ...
# 249  malai pani tapai ko video herera ni sakchu jas...
# 250                                argentina argentina
# 251                                              trujt
# 252                                           dcmarvel
# 253                                    average content
#
# [240 rows x 3 columns]

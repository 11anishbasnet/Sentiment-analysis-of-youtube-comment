# %%
import pandas as pd

import numpy as np

import string

from nltk.corpus import stopwords

from nltk import pos_tag

from nltk.corpus import wordnet

from nltk.stem import WordNetLemmatizer

import re

# %%
#function that processes the comments and returns clean_comments

def text_preprocessing(data):

    

    #convert to lowercase
    data['clean_comments'] = data['comments'].str.lower()

    #removing empty columns
    data['clean_comments'].replace('', np.nan, inplace=True)
    data.dropna(subset=['clean_comments'], inplace=True)

    #removing punctuations
    punctuation = string.punctuation
    data['clean_comments'] = data['clean_comments'].astype(str)
    data['clean_comments'] = data['clean_comments'].apply(lambda x: x.translate(str.maketrans('','',punctuation)))

    #removing stopwords
    STOPWORDS = set(stopwords.words('english'))
    data['clean_comments'] = data['clean_comments'].apply(lambda x: " ".join([w for w in x.split() if w not in STOPWORDS]))

    #remove non english words
    #WORDS = set(words.words())
    #data['clean_comments'] = data['clean_comments'].apply(lambda x: " ".join(w for w in x.split() if w in WORDS))

    #removing special characters
    data['clean_comments'] = data['clean_comments'].apply(lambda x: re.sub('[^a-zA-Z0-9]', ' ', x))
    data['clean_comments'] = data['clean_comments'].apply(lambda x: re.sub('\s+', ' ', x))

    #removing urls and html tags
    data['clean_comments'] = data['clean_comments'].apply(lambda x: re.sub(r'https?://\S+www\.\S+', ' ', x))
    data['clean_comments'] = data['clean_comments'].apply(lambda x: re.sub(r'<.*?>', ' ', x))

    #stemization
    #ps = PorterStemmer()
    #data['clean_comments'] = data['clean_comments'].apply(lambda x: " ".join([ps.stem(w) for w in x.split()]))

    #lemmatization and pos tagging
    lemmatizer = WordNetLemmatizer()
    wordnet_map = {"N":wordnet.NOUN,"V":wordnet.VERB,"J":wordnet.ADJ,"R":wordnet.ADV}
    data['clean_comments'] = data['clean_comments'].apply(lambda x: " ".join([lemmatizer.lemmatize(w,wordnet_map.get(pos[0],wordnet.NOUN)) for w, pos in pos_tag(x.split())]))
    
    #removing empty columns
    data['clean_comments'].replace('', np.nan, inplace=True)
    data.dropna(subset=['clean_comments'], inplace=True)

    #removing null value
    #data['clean_comments'].dropna(how = any, axis = 0)

    #word tokanize
    #data['clean_comments'] = data['clean_comments'].apply(lambda x: word_tokenize(x))
    #data
    
    #reset index
    data.reset_index(drop=True)
    #using globle variable i and modifying it after saving into csv
    global y
    data.to_csv("C:\\Users\\11ani\\OneDrive\\Desktop\\project 7th sem code\\clean_comments\\traindata\\"+str(y)+"tesclean.csv")
    y = y+1
    print(data)

# %%
y = 8

for i in range(0,12):
    data = pd.read_csv("C:\\Users\\11ani\\OneDrive\\Desktop\\project 7th sem code\\raw_comments\\traindata\\"+str(i)+"tes.csv", index_col=[0])
    text_preprocessing(data)
# Out:
#                                               comments  sentiments  \
# 0    I myself played cricket from grade 5 to 9 pass...           1
# 1    Love your content bro, Corruption have had des...           1
# 2    Corruption has ruined our country and you are ...           1
# 3    The effort you’re putting to research everythi...           1
# 4    My question is, are you not getting any kind o...           1
# ..                                                 ...         ...
# 317                                  Daju bhai chor ho           1
# 318                                  Thank you Dipesh.           1
# 319                                                F n           1
# 320                                          Political           1
# 321  कुनैपनि एन्फा पदाधिकारी चोखो छैन। गणेशे मुजि त...           1
#
#                                         clean_comments
# 0    play cricket grade 5 9 passionately realize cr...
# 1    love content bro corruption destroy country de...
# 2             corruption ruin country good work expose
# 3    effort you re put research everything content ...
# 4    question get kind response people make videos ...
# ..                                                 ...
# 317                                  daju bhai chor ho
# 318                                       thank dipesh
# 319                                                f n
# 320                                          political
# 321                                              karma
#
# [307 rows x 3 columns]
#                                               comments  sentiments  \
# 0    This is one quality content which  i  rarely c...           1
# 1    Most Probably the best nepali youtube channel....           1
# 2    Felt sadI wish the right candidate will hold d...           1
# 3    Future of journalism and eyes of Nepal! \n\nFi...           1
# 4    I hope soon we will have a electronic voting s...           1
# ..                                                 ...         ...
# 217          ghar ka bhaiko ya bhako sab merai ghar ho           1
# 219  Every time I watch your video at last your dep...           1
# 220                    Swagat Gyawali dai jastae aawaj           1
# 221                                         NONOTAGAIN           1
# 222              Tax kati tirna parxa ta 950 crore ko?           1
#
#                                         clean_comments
# 0    one quality content rarely find expect nepali ...
# 1    probably best nepali youtube channelwell resea...
# 2     felt sadi wish right candidate hold deserve seat
# 3    future journalism eye nepal fine thing best in...
# 4    hope soon electronic voting system put hassle ...
# ..                                                 ...
# 217          ghar ka bhaiko ya bhako sab merai ghar ho
# 219  every time watch video last depression easily ...
# 220                    swagat gyawali dai jastae aawaj
# 221                                         nonotagain
# 222               tax kati tirna parxa ta 950 crore ko
#
# [197 rows x 3 columns]
#                                              comments  sentiments  \
# 0   Seeing this type of content gives me hope\nSom...           1
# 1   this man's a gem.. this kind of video should r...           1
# 2   Politicians of Nepal are in the pockets of Ind...           1
# 3   we need these kinda informative videos. People...           1
# 4   I think this video gone be most important vide...           1
# ..                                                ...         ...
# 95                                 underrated channel           1
# 96                Finally someone is talking about it           1
# 97  Brother..\nSummary the role of Nepal in WW1&WW...           1
# 98           You r nepali dhruv rathee keep it up bro           1
# 99  you are right about unfair voter population in...           1
#
#                                        clean_comments
# 0   see type content give hope someday soon good c...
# 1                   man gem kind video reach everyone
# 2             politician nepal pocket indian lawmaker
# 3   need kinda informative videos people tend know...
# 4             think video go important video nepalese
# ..                                                ...
# 95                                 underrated channel
# 96                               finally someone talk
# 97       brother summary role nepal ww1ww2 next video
# 98                     r nepali dhruv rathee keep bro
# 99  right unfair voter population constituency man...
#
# [100 rows x 3 columns]
#                                               comments  sentiments  \
# 0    People posting thier ILLEGALLY crossing the bo...           1
# 1    This guy breaks down the cases like nobody els...           1
# 2    Man, this video gives goosebumps. Scary af. It...           1
# 3    There are so many facets to this journey. I ha...           1
# 4    As a nepalese doing buisness in both portugal ...           1
# ..                                                 ...         ...
# 335              Mero baba ni yai bato janu vako thiyo           1
# 336                                       Ramchandra 🫵           1
# 337  Bhai esto video banaayera Nepali ko beijat nag...           1
# 338  यो सब bramanbad ley garda हो...  Fuc...... Off...           1
# 339                                           Tero bau           1
#
#                                         clean_comments
# 0    people post thier illegally cross boarder jour...
# 1    guy break case like nobody else mvp dark horse...
# 2    man video give goosebump scary af really reall...
# 3    many facet journey discuss less used route int...
# 4    nepalese buisness portugal croatia sadly true ...
# ..                                                 ...
# 335              mero baba ni yai bato janu vako thiyo
# 336                                         ramchandra
# 337  bhai esto video banaayera nepali ko beijat nag...
# 338                     bramanbad ley garda fuc braman
# 339                                           tero bau
#
# [329 rows x 3 columns]

# %%
import pandas as pd

import numpy as np

import string

from nltk.corpus import stopwords

from nltk.corpus import words

from nltk.stem.porter import PorterStemmer

from nltk import pos_tag

from nltk.corpus import wordnet

from nltk.stem import WordNetLemmatizer



import re

data = pd.read_csv('2clean.csv', index_col=[0])



data
# Out:
#                                               comments  sentiments  \
# 0    Thanks to FCC for posting my Web Scraping cour...         NaN
# 1    I thought this skill would be way above my lev...         NaN
# 2    This is definitely one of the best hours I spe...         NaN
# 3    As someone rather new to coding, I've tried se...         NaN
# 4    I just have to say, this is the best webscrapi...         NaN
# ..                                                 ...         ...
# 610                              Borat teaches Python!         NaN
# 611                                                  L         NaN
# 612                       Literally a waste of my time         NaN
# 613           I stopped watching because of the accent         NaN
# 614  Please learn to pronounce 'THE' !  Gave up wat...         NaN
#
#                                         clean_comments
# 0    thanks post web scrap course huge achievement ...
# 1    thought skill would way level still student mi...
# 2    definitely one best spent quality content free...
# 3    someone rather new tried several web scrap non...
# 4                      say best course see far well do
# ..                                                 ...
# 610                                             python
# 611                                                  l
# 612                               literally waste time
# 613                                  stop watch accent
# 614        please learn pronounce give watch video min
#
# [600 rows x 3 columns]

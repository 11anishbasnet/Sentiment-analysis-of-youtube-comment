# %%
import pandas as pd

df0 = pd.read_csv("C:\\Users\\11ani\\OneDrive\\Desktop\\project 7th sem code\\clean_comments\\traindata\\0tesclean.csv", index_col=[0])
df1= pd.read_csv("C:\\Users\\11ani\\OneDrive\\Desktop\\project 7th sem code\\clean_comments\\traindata\\1tesclean.csv", index_col=[0])
df2 = pd.read_csv("C:\\Users\\11ani\\OneDrive\\Desktop\\project 7th sem code\\clean_comments\\traindata\\2tesclean.csv", index_col=[0])
df3 = pd.read_csv("C:\\Users\\11ani\\OneDrive\\Desktop\\project 7th sem code\\clean_comments\\traindata\\3tesclean.csv", index_col=[0])
df4 = pd.read_csv("C:\\Users\\11ani\\OneDrive\\Desktop\\project 7th sem code\\clean_comments\\traindata\\4tesclean.csv", index_col=[0])
df5 = pd.read_csv("C:\\Users\\11ani\\OneDrive\\Desktop\\project 7th sem code\\clean_comments\\traindata\\5tesclean.csv", index_col=[0])
df6= pd.read_csv("C:\\Users\\11ani\\OneDrive\\Desktop\\project 7th sem code\\clean_comments\\traindata\\6tesclean.csv", index_col=[0])
df7 = pd.read_csv("C:\\Users\\11ani\\OneDrive\\Desktop\\project 7th sem code\\clean_comments\\traindata\\7tesclean.csv", index_col=[0])
df8 = pd.read_csv("C:\\Users\\11ani\\OneDrive\\Desktop\\project 7th sem code\\clean_comments\\traindata\\8tesclean.csv", index_col=[0])
df9 = pd.read_csv("C:\\Users\\11ani\\OneDrive\\Desktop\\project 7th sem code\\clean_comments\\traindata\\9tesclean.csv", index_col=[0])
df10 = pd.read_csv("C:\\Users\\11ani\\OneDrive\\Desktop\\project 7th sem code\\clean_comments\\traindata\\10tesclean.csv", index_col=[0])
df11 = pd.read_csv("C:\\Users\\11ani\\OneDrive\\Desktop\\project 7th sem code\\clean_comments\\traindata\\11tesclean.csv", index_col=[0])

df = pd.concat([df0,df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11],ignore_index = True)
df.to_csv("C:\\Users\\11ani\\OneDrive\\Desktop\\project 7th sem code\\clean_comments\\traindata\\train.csv")
df
# Out:
#                                                comments  sentiments  \
# 0     What I'm going to say is that I never imagined...           0
# 1     Please continue this series. What happened aft...           1
# 2     Would love to see more of our history's video,...           1
# 3     They will never be forgotten. Salute to our ma...           1
# 4     The level of editing , animation , voice, rese...           1
# ...                                                 ...         ...
# 3984              Mero baba ni yai bato janu vako thiyo           1
# 3985                                       Ramchandra 🫵           1
# 3986  Bhai esto video banaayera Nepali ko beijat nag...           1
# 3987  यो सब bramanbad ley garda हो...  Fuc...... Off...           1
# 3988                                           Tero bau           1
#
#                                          clean_comments
# 0     im go say never imagine member nation finest t...
# ...
